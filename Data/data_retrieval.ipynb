# %% [markdown]
# ## We will use xena's API to retrieve our data.

# %%
import pandas as pd

# %%
import xenaPython as xena

# %%
help(xena)
# Out:
# Help on package xenaPython:
#
# NAME
#     xenaPython - Methods for querying data from UCSC Xena hubs
#
# DESCRIPTION
#     Data rows are associated with "sample" IDs.
#     Sample IDs are unique within a "cohort".
#     A "dataset" is a particular assay of a cohort, e.g. gene expression.
#     Datasets have associated metadata, specifying their data type and cohort.
#
#     There are three primary data types: dense matrix (samples by probes),
#     sparse (sample, position, variant), and segmented (sample, position, value).
#
#
#     Dense matrices can be genotypic or phenotypic. Phenotypic matrices have
#     associated field metadata (descriptive names, codes, etc.).
#
#     Genotypic matricies may have an associated probeMap, which maps probes to
#     genomic locations. If a matrix has hugo probeMap, the probes themselves
#     are gene names. Otherwise, a probeMap is used to map a gene location to a
#     set of probes.
#
# PACKAGE CONTENTS
#     convert
#     example
#     jupyter
#     xenaAPI
#     xenaQuery
#
# FUNCTIONS
#     all_cohorts(host, exclude)
#
#     all_datasets(host)
#
#     all_datasets_n(host)
#         Count the number datasets with non-null cohort
#
#     all_field_metadata(host, dataset)
#         Metadata for all dataset fields (phenotypic datasets)
#
#     cohort_samples(host, cohort, limit)
#         All samples in cohort
#
#     cohort_summary(host, exclude)
#         Count datasets per-cohort, excluding the given dataset types
#
#         xena.cohort_summary(xena.PUBLIC_HUBS["pancanAtlasHub"], ["probeMap"])
#
#     dataset_fetch(host, dataset, samples, probes)
#         Probe values for give samples
#
#     dataset_field(host, dataset)
#         All field (probe) names in dataset
#
#     dataset_field_examples(host, dataset, count)
#         Field names in dataset, up to <count>
#
#     dataset_field_n(host, dataset)
#         Number of fields in dataset
#
#     dataset_gene_probe_avg(host, dataset, samples, genes)
#         Probe average, per-gene, for given samples
#
#     dataset_gene_probes_values(host, dataset, samples, genes)
#         Probe values in gene, and probe genomic positions, for given samples
#
#     dataset_list(host, cohorts)
#         Dataset metadata for datasets in the given cohorts
#
#     dataset_metadata(host, dataset)
#         Dataset metadata
#
#     dataset_probe_signature(host, dataset, samples, probes, weights)
#         Computed probe signature for given samples and weight array
#
#     dataset_probe_values(host, dataset, samples, probes)
#         Probe values for given samples, and probe genomic positions
#
#         host = xena.PUBLIC_HUBS["pancanAtlasHub"]
#         dataset = "EB++AdjustPANCAN_IlluminaHiSeq_RNASeqV2.geneExp.xena"
#         samples = xena.dataset_samples(host, dataset, None)
#         [position, [foxm1, tp53]] = xena.dataset_probe_values(host, dataset, samples, ["FOXM1", "TP53"])
#
#     dataset_samples(host, dataset, limit)
#         All samples in dataset (optional limit)
#
#         samples = xena.dataset_samples(xena.PUBLIC_HUBS["pancanAtlasHub"], "EB++AdjustPANCAN_IlluminaHiSeq_RNASeqV2.geneExp.xena", None)
#
#     dataset_samples_n_dense_matrix(host, dataset)
#         All samples in dataset (faster, for dense matrix dataset only)
#
#     dataset_sources(host, dataset)
#
#     dataset_status(host, dataset)
#
#     datasets_null_rows(host)
#
#     feature_list(host, dataset)
#         Dataset field names and long titles (phenotypic datasets)
#
#     field_codes(host, dataset, fields)
#         Codes for categorical fields
#
#     field_metadata(host, dataset, fields)
#         Metadata for given fields (phenotypic datasets)
#
#     gene_transcripts(host, dataset, gene)
#         Gene transcripts
#
#     load_file(name, host='http://127.0.0.1:7222')
#         # XXX need timeout and error handling
#         # should this do the file copy, too?
#
#     load_ipython_extension(ipython)
#         jupyter support method
#
#     match_fields(host, dataset, names)
#         Find fields matching names (must be lower-case)
#
#     open_browser(url='heatmap/', columns=[])
#
#     probe_count(host, dataset)
#
#     probemap_list(host)
#         Find probemaps
#
#     ref_gene_exons(host, dataset, genes)
#         Gene model
#
#     ref_gene_position(host, dataset, gene)
#         Gene position from gene model
#
#     ref_gene_range(host, dataset, chr, start, end)
#         Gene models overlapping range
#
#     segment_data_examples(host, dataset, count)
#         Initial segmented data rows, with limit
#
#     segmented_data_range(host, dataset, samples, chr, start, end)
#         Segmented (copy number) data overlapping range
#
#     sparse_data(host, dataset, samples, genes)
#         Sparse (mutation) data rows for genes
#
#     sparse_data_examples(host, dataset, count)
#         Initial sparse data rows, with limit
#
#     sparse_data_match_field(host, field, dataset, names)
#         Genes in sparse (mutation) dataset matching given names
#
#     sparse_data_match_field_slow(host, field, dataset, names)
#         Genes in sparse (mutation) dataset matching given names, case-insensitive (names must be lower-case)
#
#     sparse_data_match_partial_field(host, field, dataset, names, limit)
#         Partial match genes in sparse (mutation) dataset
#
#     sparse_data_range(host, dataset, samples, chr, start, end)
#         Sparse (mutation) data rows overlapping the given range, for the given samples
#
#     transcript_expression(host, transcripts, studyA, subtypeA, studyB, subtypeB, dataset)
#
#     unload_ipython_extension(ipython)
#         jupyter support method
#
# DATA
#     LOCAL_HUB = 'https://local.xena.ucsc.edu:7223'
#     PUBLIC_HUBS = {'gdcHub': 'https://gdc.xenahubs.net', 'icgcHub': 'https...
#     QUERIES = {'all_cohorts': ';allCohorts\n(fn [exclude]\n\t(map :cohort\...
#     __warningregistry__ = {'version': 17, ('Possible nested set at positio...
#     excludeType = ['probeMap', 'probemap', 'genePredExt']
#     ipython_instance = None
#
# FILE
#     /home/ubuntu/anaconda3/lib/python3.7/site-packages/xenaPython/__init__.py

# %%
host = 'https://toil.xenahubs.net'

# %% [markdown]
# ### Our dataset is the RSEM expected_count (DESeq2 standardized)
# ### i.e. 'TCGA-GTEx-TARGET-gene-exp-counts.deseq2-normalized.log2' from the above

# %%
dataset = 'TCGA-GTEx-TARGET-gene-exp-counts.deseq2-normalized.log2'

# %%
xena.dataset_samples_n_dense_matrix(host, dataset) #That is the full number of samples
# Out:
# [19039]

# %%
samples = xena.dataset_samples(host, dataset,19039) # All of the samples

# %%
len(samples)
# Out:
# 19039

# %%
samples[10]
# Out:
# 'TCGA-DX-A7EO-01'

# %% [markdown]
# ### We will split our data into TCGA , TARGET and GTEX samples. This will be done in order for us to be able to load datasets as well as make the analysis better

# %%
tcga = []
target = []
gtex = []

for i in range(len(samples)):
    if samples[i].startswith('TCGA'):
        tcga.append(samples[i])
    elif samples[i].startswith('TARGET'):
        target.append(samples[i])
    else:
        gtex.append(samples[i])

# %%
len(tcga)
# Out:
# 10530

# %%
len(target)
# Out:
# 734

# %%
len(gtex)
# Out:
# 7775

# %%
genes = xena.dataset_field(host, dataset) #all of the genes

# %%
len(genes)
# Out:
# 60499

# %%
#Let's create a function that we pass batches of genes and samples and creates a dataframe 

def pos(samples, genes):
    cohort = 'TCGA TARGET GTEx'
    host = 'https://toil.xenahubs.net'
    dataset = 'TCGA-GTEx-TARGET-gene-exp-counts.deseq2-normalized.log2'
    
    positions = xena.dataset_probe_values(host, dataset, samples, genes) #this returns the normalized position of the genes
    gene_pos = dict(zip(genes, positions[1]))
    df = pd.DataFrame.from_dict(gene_pos)
    df.index = samples
    
    return df

# %%
chunks = [genes[x:x+1000] for x in range(0, len(genes), 1000)] #let's take chuncks of 1000 genes at a time

# %%
len(chunks)
# Out:
# 61

# %%
df1 = pos(samples, genes[9800:9900])

# %%
df1.head()
# Out:
#                  ENSG00000154719.13  ENSG00000154721.14  ENSG00000154723.12  \
# TCGA-AD-5900-01              10.100               8.004               11.78
# TCGA-BP-4968-01              10.600               9.964               12.56
# TCGA-NG-A4VU-01              10.210              10.730               12.82
# TCGA-CG-4305-01              10.200               8.962               11.79
# TCGA-AO-A03M-01               9.494               9.442               11.82
#
#                  ENSG00000154727.10  ENSG00000154734.14  ENSG00000154736.5  \
# TCGA-AD-5900-01               10.34               9.243              6.769
# TCGA-BP-4968-01               11.11              12.880              9.522
# TCGA-NG-A4VU-01               11.04              11.350             10.420
# TCGA-CG-4305-01               11.11              10.100              8.454
# TCGA-AO-A03M-01               10.82              11.680              8.287
#
#                  ENSG00000154743.17  ENSG00000154760.13  ENSG00000154764.5  \
# TCGA-AD-5900-01               8.903               9.766             0.0000
# TCGA-BP-4968-01               8.345              11.270             2.3690
# TCGA-NG-A4VU-01               8.149               7.096             5.5670
# TCGA-CG-4305-01              10.140              10.170             1.4770
# TCGA-AO-A03M-01               7.884               8.230             0.6768
#
#                  ENSG00000154767.14  ...  ENSG00000155629.14  \
# TCGA-AD-5900-01              10.950  ...              11.080
# TCGA-BP-4968-01              11.260  ...              11.440
# TCGA-NG-A4VU-01               9.727  ...               9.689
# TCGA-CG-4305-01              10.730  ...              11.320
# TCGA-AO-A03M-01              10.990  ...              10.400
#
#                  ENSG00000155636.14  ENSG00000155640.6  ENSG00000155657.23  \
# TCGA-AD-5900-01               8.503              8.026               6.058
# TCGA-BP-4968-01               9.026              6.116               8.028
# TCGA-NG-A4VU-01               9.037              7.748              16.150
# TCGA-CG-4305-01               7.934              9.116               8.587
# TCGA-AO-A03M-01               8.733              9.143               7.361
#
#                  ENSG00000155659.14  ENSG00000155660.10  ENSG00000155666.11  \
# TCGA-AD-5900-01               9.794               13.72               7.234
# TCGA-BP-4968-01               9.687               13.67               8.549
# TCGA-NG-A4VU-01               8.179               12.84               7.564
# TCGA-CG-4305-01              11.260               13.80               7.140
# TCGA-AO-A03M-01               9.391               14.79               7.638
#
#                  ENSG00000155714.13  ENSG00000155719.16  ENSG00000155729.12
# TCGA-AD-5900-01               1.551               3.413               9.271
# TCGA-BP-4968-01               2.116               6.310              10.040
# TCGA-NG-A4VU-01               2.150               4.545               8.947
# TCGA-CG-4305-01               1.878               4.302               9.577
# TCGA-AO-A03M-01               0.000               4.533               9.623
#
# [5 rows x 100 columns]

# %%
df1.describe()
# Out:
#        ENSG00000154719.13  ENSG00000154721.14  ENSG00000154723.12  \
# count        19039.000000        19039.000000        19039.000000
# mean             9.216853            8.893895           11.423807
# std              0.964574            1.957889            1.098617
# min              0.000000            0.000000            0.000000
# 25%              8.505000            7.790000           10.720000
# 50%              9.286000            9.085000           11.480000
# 75%              9.890000           10.210000           12.120000
# max             13.100000           15.510000           16.740000
#
#        ENSG00000154727.10  ENSG00000154734.14  ENSG00000154736.5  \
# count        19039.000000        19039.000000       19039.000000
# mean            10.287863           11.049464           7.910874
# std              0.927541            2.353984           2.382528
# min              0.000000            0.000000           0.000000
# 25%              9.663500            9.874500           6.663000
# 50%             10.220000           11.270000           8.174000
# 75%             10.930000           12.605000           9.446000
# max             13.990000           17.040000          16.480000
#
#        ENSG00000154743.17  ENSG00000154760.13  ENSG00000154764.5  \
# count        19039.000000        19039.000000       19039.000000
# mean             8.506836            8.472479           3.440166
# std              0.823556            2.166364           3.372494
# min              0.000000            0.000000           0.000000
# 25%              8.085000            6.862500           0.000000
# 50%              8.472000            8.499000           2.330000
# 75%              8.954000           10.170000           6.031000
# max             12.850000           14.840000          15.420000
#
#        ENSG00000154767.14  ...  ENSG00000155629.14  ENSG00000155636.14  \
# count        19039.000000  ...        19039.000000        19039.000000
# mean            10.856846  ...            8.838714            8.388410
# std              0.843610  ...            2.491209            0.737831
# min              0.000000  ...            0.000000            0.000000
# 25%             10.390000  ...            7.031000            7.954000
# 50%             10.850000  ...            8.911000            8.374000
# 75%             11.320000  ...           10.600000            8.873000
# max             14.350000  ...           16.520000           10.800000
#
#        ENSG00000155640.6  ENSG00000155657.23  ENSG00000155659.14  \
# count       19039.000000        19039.000000        19039.000000
# mean            7.110810            8.789456            8.731416
# std             1.353833            2.617947            2.492504
# min             0.000000            0.000000            0.000000
# 25%             6.107000            7.493000            7.307500
# 50%             6.956000            8.524000            8.887000
# 75%             8.010000            9.362000           10.410000
# max            12.450000           24.160000           16.810000
#
#        ENSG00000155660.10  ENSG00000155666.11  ENSG00000155714.13  \
# count        19039.000000        19039.000000        19039.000000
# mean            12.326441            7.433425            1.930716
# std              1.839742            1.043842            1.407380
# min              0.000000            0.000000            0.000000
# 25%             10.830000            6.731000            1.007500
# 50%             12.510000            7.401000            1.824000
# 75%             13.820000            8.047000            2.681000
# max             17.530000           13.910000            9.934000
#
#        ENSG00000155719.16  ENSG00000155729.12
# count        19039.000000        19039.000000
# mean             3.616432            9.241333
# std              1.957262            0.865747
# min              0.000000            0.000000
# 25%              2.302000            8.673000
# 50%              3.660000            9.203000
# 75%              4.909000            9.866000
# max             12.350000           12.490000
#
# [8 rows x 100 columns]

# %% [markdown]
# ### We will work with batches of 1000 features. According to:
# ### Jaskowiak, P. A., Costa, I. G., & Campello, R. J. G. B. (2018). Clustering of RNA-Seq samples: Comparison study on cancer data. Methods, 132, 42–49. https://doi.org/10.1016/j.ymeth.2017.07.023 ,
# ### using samples with 1000 features at a time, can lead to superior results in clustering. We will begin our analysis with datasets of 1000 features at a time

# %% [markdown]
# ### We will focus our analysis in tcga samples for the time being
#
# ### According to Vidman, L., Källberg, D., &#38; Rydén, P. (2019). Cluster analysis on high dimensional RNA-seq data with applications to cancer research - An evaluation study. PLoS ONE, 1412). https://doi.org/10.1371/journal.pone.0219102 genes  that either showed
# ### 1)  small variation between samples (i.e. standard deviation less than  0.5)
# ### 2) or were 0 everywhere

# %%
#Function for use if we decide to get all of the data
nums = list(range(0,61,1))

names = ['df'+str(nums[x]) for x in range(len(nums))]


for i in range(len(names)):
    names[i] = pos(tcga, chunks[i])
    names[i] = names[i].loc[:, (names[i]!= 0).any(axis=0)]
    names[i].drop(names[i].std()[names[i].std() < 0.5].index.values, axis=1)

# %%
dataframes = []
for i in range(len(names)):
    dataframes.append(names[i])

# %%
df = pd.concat([df.set_index(df.index) for df in dataframes], ignore_index=False, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10530 entries, TCGA-AD-5900-01 to TCGA-FU-A3HZ-01
# Columns: 57060 entries, ENSG00000000003.14 to sampleID
# dtypes: float64(57059), int64(1)
# memory usage: 4.5+ GB

# %%
df.head()
# Out:
#                  ENSG00000000003.14  ENSG00000000005.5  ENSG00000000419.12  \
# TCGA-AD-5900-01              10.670              0.000               10.38
# TCGA-BP-4968-01              11.580              5.298               10.51
# TCGA-NG-A4VU-01               9.693              3.262               11.00
# TCGA-CG-4305-01              10.260              0.000               11.10
# TCGA-AO-A03M-01              10.100              1.997               11.74
#
#                  ENSG00000000457.13  ENSG00000000460.16  ENSG00000000938.12  \
# TCGA-AD-5900-01               9.036               8.496               8.563
# TCGA-BP-4968-01               9.421               7.842              10.280
# TCGA-NG-A4VU-01               9.155               9.683               7.383
# TCGA-CG-4305-01               9.465               9.078               9.173
# TCGA-AO-A03M-01              10.380               9.157               8.509
#
#                  ENSG00000000971.15  ENSG00000001036.13  ENSG00000001084.10  \
# TCGA-AD-5900-01              10.050               11.44              10.860
# TCGA-BP-4968-01              12.410               12.69              10.940
# TCGA-NG-A4VU-01               8.848               11.19               9.806
# TCGA-CG-4305-01              12.320               12.09              12.220
# TCGA-AO-A03M-01              11.630               11.80              10.580
#
#                  ENSG00000001167.14  ...  ENSG00000282785.1  \
# TCGA-AD-5900-01               9.896  ...              1.551
# TCGA-BP-4968-01              10.290  ...              0.000
# TCGA-NG-A4VU-01              11.180  ...              0.000
# TCGA-CG-4305-01              11.040  ...              6.791
# TCGA-AO-A03M-01              11.680  ...              0.000
#
#                  ENSG00000282787.1  ENSG00000282793.1  ENSG00000282795.1  \
# TCGA-AD-5900-01              1.962             0.9745              0.000
# TCGA-BP-4968-01              2.116             0.8746              0.000
# TCGA-NG-A4VU-01              2.977             3.2620              0.000
# TCGA-CG-4305-01              1.878             0.0000              0.000
# TCGA-AO-A03M-01              3.230             0.0000              1.136
#
#                  ENSG00000282798.1  ENSG00000282804.1  ENSG00000282807.1  \
# TCGA-AD-5900-01              3.538             0.0000             0.0000
# TCGA-BP-4968-01              2.773             0.8746             0.8746
# TCGA-NG-A4VU-01              2.977             0.0000             0.0000
# TCGA-CG-4305-01              6.066             0.0000             0.0000
# TCGA-AO-A03M-01              4.050             0.6768             0.0000
#
#                  ENSG00000282815.1  ENSG00000282816.1  sampleID
# TCGA-AD-5900-01             0.0000                0.0         0
# TCGA-BP-4968-01             0.8746                0.0         1
# TCGA-NG-A4VU-01             0.0000                0.0         2
# TCGA-CG-4305-01             0.0000                0.0         3
# TCGA-AO-A03M-01             3.8250                0.0         4
#
# [5 rows x 57060 columns]

# %%
len(df)
# Out:
# 10530

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10530 entries, TCGA-AD-5900-01 to TCGA-FU-A3HZ-01
# Columns: 57060 entries, ENSG00000000003.14 to sampleID
# dtypes: float64(57059), int64(1)
# memory usage: 4.5+ GB

# %% [markdown]
# ## Now we will only keep the genes that are protein coding. Using the ensemble IDs from HGNC we were able to retrieve a dataset that contains only protein coding genes

# %%
protein_cd = pd.read_csv('../Data/protein_coding_genes.csv')

# %%
protein_cd.head()
# Out:
#   Ensembl ID(supplied by Ensembl)
# 0                 ENSG00000121410
# 1                 ENSG00000148584
# 2                 ENSG00000175899
# 3                 ENSG00000166535
# 4                 ENSG00000184389

# %%
protein_cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19148 entries, 0 to 19147
# Data columns (total 1 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ensembl ID(supplied by Ensembl)  19148 non-null  object
# dtypes: object(1)
# memory usage: 149.7+ KB

# %%
genes_to_keep = list(protein_cd['Ensembl ID(supplied by Ensembl)']) #make a list containing protein coding genes

# %%
all_cols = list(df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-0237e72ac8e7> in <module>
# ----> 1 all_cols = list(df.columns)
#
# NameError: name 'df' is not defined

# %%
all_cols[0].split('.')[0]
# Out:
# 'ENSG00000000003'

# %%
our_genes = []
for i in range(len(all_cols)):
    if all_cols[i].split('.')[0] in genes_to_keep:
        our_genes.append(all_cols[i])

# %%
len(our_genes)
# Out:
# 19037

# %%
df_final = df[our_genes]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10530 entries, TCGA-AD-5900-01 to TCGA-FU-A3HZ-01
# Columns: 19037 entries, ENSG00000000003.14 to ENSG00000282815.1
# dtypes: float64(19037)
# memory usage: 1.5+ GB

# %%
df_final.to_csv('../Data/data.csv')

# %%
## We will now repeat the above procedure for the GTEX samples

# %%
#Function for use if we decide to get all of the data
num = list(range(0,61,1))

names_gtex = ['df'+str(num[x]) for x in range(len(num))]


for i in range(len(names_gtex)):
    names_gtex[i] = pos(gtex, chunks[i])
    names_gtex[i] = names_gtex[i].loc[:, (names_gtex[i]!= 0).any(axis=0)]
    names_gtex[i].drop(names_gtex[i].std()[names_gtex[i].std() < 0.5].index.values, axis=1)

# %%
dataframes_gtex = []
for i in range(len(names_gtex)):
    dataframes_gtex.append(names_gtex[i])

# %%
df_gtex = pd.concat([df.set_index(df.index) for df in dataframes_gtex], ignore_index=False, axis=1)

# %%
df_gtex.head()
# Out:
#                           ENSG00000000003.14  ENSG00000000005.5  \
# GTEX-UTHO-1226-SM-3GAEE                9.124              0.000
# GTEX-146FH-1726-SM-5QGQ2              11.360              0.000
# GTEX-QDT8-0126-SM-48TZ1                8.926              6.679
# GTEX-QCQG-1326-SM-48U24                9.862              1.436
# GTEX-WZTO-2926-SM-3NM9I                8.429              2.591
#
#                           ENSG00000000419.12  ENSG00000000457.13  \
# GTEX-UTHO-1226-SM-3GAEE                9.375               8.514
# GTEX-146FH-1726-SM-5QGQ2               9.341               9.245
# GTEX-QDT8-0126-SM-48TZ1                9.009               9.016
# GTEX-QCQG-1326-SM-48U24                9.138               8.547
# GTEX-WZTO-2926-SM-3NM9I                9.153               8.497
#
#                           ENSG00000000460.16  ENSG00000000938.12  \
# GTEX-UTHO-1226-SM-3GAEE                7.637              10.110
# GTEX-146FH-1726-SM-5QGQ2               7.970               7.402
# GTEX-QDT8-0126-SM-48TZ1                7.294               9.091
# GTEX-QCQG-1326-SM-48U24                7.232               8.685
# GTEX-WZTO-2926-SM-3NM9I                6.185               7.117
#
#                           ENSG00000000971.15  ENSG00000001036.13  \
# GTEX-UTHO-1226-SM-3GAEE               15.720              10.170
# GTEX-146FH-1726-SM-5QGQ2              10.620               8.902
# GTEX-QDT8-0126-SM-48TZ1               12.820               9.356
# GTEX-QCQG-1326-SM-48U24                7.618              10.200
# GTEX-WZTO-2926-SM-3NM9I                9.470               8.746
#
#                           ENSG00000001084.10  ENSG00000001167.14  ...  \
# GTEX-UTHO-1226-SM-3GAEE                8.951              10.190  ...
# GTEX-146FH-1726-SM-5QGQ2              10.260               9.446  ...
# GTEX-QDT8-0126-SM-48TZ1                9.262               9.365  ...
# GTEX-QCQG-1326-SM-48U24                9.925               9.481  ...
# GTEX-WZTO-2926-SM-3NM9I                9.765               9.334  ...
#
#                           ENSG00000282785.1  ENSG00000282787.1  \
# GTEX-UTHO-1226-SM-3GAEE                 0.0              0.000
# GTEX-146FH-1726-SM-5QGQ2                0.0              0.000
# GTEX-QDT8-0126-SM-48TZ1                 0.0              2.122
# GTEX-QCQG-1326-SM-48U24                 0.0              3.491
# GTEX-WZTO-2926-SM-3NM9I                 0.0              0.000
#
#                           ENSG00000282793.1  ENSG00000282795.1  \
# GTEX-UTHO-1226-SM-3GAEE                 0.0                0.0
# GTEX-146FH-1726-SM-5QGQ2                0.0                0.0
# GTEX-QDT8-0126-SM-48TZ1                 0.0                0.0
# GTEX-QCQG-1326-SM-48U24                 0.0                0.0
# GTEX-WZTO-2926-SM-3NM9I                 0.0                0.0
#
#                           ENSG00000282798.1  ENSG00000282804.1  \
# GTEX-UTHO-1226-SM-3GAEE               3.265             0.0000
# GTEX-146FH-1726-SM-5QGQ2              4.704             0.0000
# GTEX-QDT8-0126-SM-48TZ1               3.573             0.0000
# GTEX-QCQG-1326-SM-48U24               3.694             0.8901
# GTEX-WZTO-2926-SM-3NM9I               3.799             0.0000
#
#                           ENSG00000282807.1  ENSG00000282815.1  \
# GTEX-UTHO-1226-SM-3GAEE                 0.0              0.000
# GTEX-146FH-1726-SM-5QGQ2                0.0              0.000
# GTEX-QDT8-0126-SM-48TZ1                 0.0              2.122
# GTEX-QCQG-1326-SM-48U24                 0.0              0.000
# GTEX-WZTO-2926-SM-3NM9I                 0.0              1.284
#
#                           ENSG00000282816.1  sampleID
# GTEX-UTHO-1226-SM-3GAEE                 0.0     10530
# GTEX-146FH-1726-SM-5QGQ2                0.0     10531
# GTEX-QDT8-0126-SM-48TZ1                 0.0     10532
# GTEX-QCQG-1326-SM-48U24                 0.0     10533
# GTEX-WZTO-2926-SM-3NM9I                 0.0     10534
#
# [5 rows x 55539 columns]

# %%
all_cols_gtex = list(df_gtex.columns)

# %%
our_genes_gtex = []
for i in range(len(all_cols_gtex)):
    if all_cols_gtex[i].split('.')[0] in genes_to_keep:
        our_genes_gtex.append(all_cols_gtex[i])

# %%
#again keep only the protein coding genes

df_gtex = df_gtex[our_genes_gtex]

# %%
df_gtex.head()
# Out:
#                           ENSG00000000003.14  ENSG00000000005.5  \
# GTEX-UTHO-1226-SM-3GAEE                9.124              0.000
# GTEX-146FH-1726-SM-5QGQ2              11.360              0.000
# GTEX-QDT8-0126-SM-48TZ1                8.926              6.679
# GTEX-QCQG-1326-SM-48U24                9.862              1.436
# GTEX-WZTO-2926-SM-3NM9I                8.429              2.591
#
#                           ENSG00000000419.12  ENSG00000000457.13  \
# GTEX-UTHO-1226-SM-3GAEE                9.375               8.514
# GTEX-146FH-1726-SM-5QGQ2               9.341               9.245
# GTEX-QDT8-0126-SM-48TZ1                9.009               9.016
# GTEX-QCQG-1326-SM-48U24                9.138               8.547
# GTEX-WZTO-2926-SM-3NM9I                9.153               8.497
#
#                           ENSG00000000460.16  ENSG00000000938.12  \
# GTEX-UTHO-1226-SM-3GAEE                7.637              10.110
# GTEX-146FH-1726-SM-5QGQ2               7.970               7.402
# GTEX-QDT8-0126-SM-48TZ1                7.294               9.091
# GTEX-QCQG-1326-SM-48U24                7.232               8.685
# GTEX-WZTO-2926-SM-3NM9I                6.185               7.117
#
#                           ENSG00000000971.15  ENSG00000001036.13  \
# GTEX-UTHO-1226-SM-3GAEE               15.720              10.170
# GTEX-146FH-1726-SM-5QGQ2              10.620               8.902
# GTEX-QDT8-0126-SM-48TZ1               12.820               9.356
# GTEX-QCQG-1326-SM-48U24                7.618              10.200
# GTEX-WZTO-2926-SM-3NM9I                9.470               8.746
#
#                           ENSG00000001084.10  ENSG00000001167.14  ...  \
# GTEX-UTHO-1226-SM-3GAEE                8.951              10.190  ...
# GTEX-146FH-1726-SM-5QGQ2              10.260               9.446  ...
# GTEX-QDT8-0126-SM-48TZ1                9.262               9.365  ...
# GTEX-QCQG-1326-SM-48U24                9.925               9.481  ...
# GTEX-WZTO-2926-SM-3NM9I                9.765               9.334  ...
#
#                           ENSG00000280314.1  ENSG00000280670.2  \
# GTEX-UTHO-1226-SM-3GAEE                 0.0              5.260
# GTEX-146FH-1726-SM-5QGQ2                0.0              6.454
# GTEX-QDT8-0126-SM-48TZ1                 0.0              4.563
# GTEX-QCQG-1326-SM-48U24                 0.0              7.507
# GTEX-WZTO-2926-SM-3NM9I                 0.0              7.627
#
#                           ENSG00000280789.1  ENSG00000280969.1  \
# GTEX-UTHO-1226-SM-3GAEE               9.723             0.0000
# GTEX-146FH-1726-SM-5QGQ2              9.839             0.0000
# GTEX-QDT8-0126-SM-48TZ1               9.641             0.0000
# GTEX-QCQG-1326-SM-48U24              10.710             0.0000
# GTEX-WZTO-2926-SM-3NM9I              10.450             0.7804
#
#                           ENSG00000281106.2  ENSG00000281991.1  \
# GTEX-UTHO-1226-SM-3GAEE               6.241              4.746
# GTEX-146FH-1726-SM-5QGQ2              2.861              8.651
# GTEX-QDT8-0126-SM-48TZ1               2.780              8.876
# GTEX-QCQG-1326-SM-48U24               2.614              7.030
# GTEX-WZTO-2926-SM-3NM9I               5.850              6.773
#
#                           ENSG00000282419.1  ENSG00000282608.1  \
# GTEX-UTHO-1226-SM-3GAEE                 0.0              7.460
# GTEX-146FH-1726-SM-5QGQ2                0.0              5.521
# GTEX-QDT8-0126-SM-48TZ1                 0.0              6.825
# GTEX-QCQG-1326-SM-48U24                 0.0              5.300
# GTEX-WZTO-2926-SM-3NM9I                 0.0              4.961
#
#                           ENSG00000282757.1  ENSG00000282815.1
# GTEX-UTHO-1226-SM-3GAEE                 0.0              0.000
# GTEX-146FH-1726-SM-5QGQ2                0.0              0.000
# GTEX-QDT8-0126-SM-48TZ1                 0.0              2.122
# GTEX-QCQG-1326-SM-48U24                 0.0              0.000
# GTEX-WZTO-2926-SM-3NM9I                 0.0              1.284
#
# [5 rows x 19036 columns]

# %%
df_gtex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7775 entries, GTEX-UTHO-1226-SM-3GAEE to GTEX-12BJ1-0426-SM-5FQSO
# Columns: 19036 entries, ENSG00000000003.14 to ENSG00000282815.1
# dtypes: float64(19036)
# memory usage: 1.1+ GB

# %%
df_gtex.to_csv('../Data/df_gtex.csv')
